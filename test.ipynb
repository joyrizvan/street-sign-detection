# %%
from ultralytics import YOLO
import cv2

# %%
# Load pre-trained YOLOv8 model (trained on COCO dataset)
model = YOLO("traffic-signs.pt")  # Load a custom model

# %%
# Load an image with road signs
img = cv2.imread('yeild2.jpg')
img = cv2.resize(img, (640, 640))  # Resize for speed

# %%
# Run object detection
results = model(img)
# Out:
# 0: 640x640 1 speed_limit_90, 1 stop, 1565.0ms
# Speed: 13.1ms preprocess, 1565.0ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Variable to store detected sign
detected_sign = None  

# Get detected objects
for result in results:
    for box in result.boxes:
        class_id = int(box.cls[0])  # Get class ID
        class_name = model.names[class_id]  # Get class name from COCO dataset

        # If "stop sign" is detected, store it in the variable
        if class_name == "stop sign":
            detected_sign = "STOP SIGN"

# Print the detected sign
if detected_sign:
    print("Detected:", detected_sign)
else:
    print("No sign detected")
# Out:
# No sign detected

# %%
# Display results using OpenCV
img_with_boxes = results[0].plot()
cv2.imshow("YOLOv8 Detection", img_with_boxes)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Use laptop feed to detect signs

# %%
from ultralytics import YOLO
import cv2
import torch

# Load custom-trained traffic sign detection model
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = YOLO("traffic-signs.pt").to(device)  # Use your trained model

# Open webcam
cap = cv2.VideoCapture(0)  # 0 = default webcam

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Stop if there's an issue with the webcam

    # Run YOLO detection on the frame
    results = model(frame, conf=0.6)  # Adjust confidence threshold if needed

    # Process detections
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
            class_id = int(box.cls[0])  # Get class ID
            class_name = model.names[class_id]  # Get detected class name

            # Draw bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Display sign name
            cv2.putText(frame, class_name, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Print detected sign in console
            print(f"Detected: {class_name}")

    # Show video feed with detections
    cv2.imshow("Traffic Sign Detection", frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 17079.6ms
# Speed: 71.0ms preprocess, 17079.6ms inference, 12.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9573.3ms
# Speed: 284.5ms preprocess, 9573.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5211.1ms
# Speed: 138.3ms preprocess, 5211.1ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 3731.4ms
# Speed: 5.8ms preprocess, 3731.4ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14615.8ms
# Speed: 93.5ms preprocess, 14615.8ms inference, 12.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 2561.3ms
# Speed: 346.3ms preprocess, 2561.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1741.6ms
# Speed: 7.3ms preprocess, 1741.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1800.6ms
# Speed: 17.6ms preprocess, 1800.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1960.0ms
# Speed: 21.9ms preprocess, 1960.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1505.2ms
# Speed: 21.0ms preprocess, 1505.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1452.1ms
# Speed: 5.7ms preprocess, 1452.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1456.4ms
# Speed: 30.8ms preprocess, 1456.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1401.1ms
# Speed: 5.7ms preprocess, 1401.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1532.7ms
# Speed: 7.0ms preprocess, 1532.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1427.5ms
# Speed: 6.7ms preprocess, 1427.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1282.6ms
# Speed: 8.1ms preprocess, 1282.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1257.2ms
# Speed: 5.5ms preprocess, 1257.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1213.0ms
# Speed: 5.9ms preprocess, 1213.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1231.9ms
# Speed: 3.8ms preprocess, 1231.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1285.6ms
# Speed: 26.9ms preprocess, 1285.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1473.4ms
# Speed: 6.1ms preprocess, 1473.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1270.1ms
# Speed: 4.9ms preprocess, 1270.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1355.8ms
# Speed: 5.4ms preprocess, 1355.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1269.0ms
# Speed: 6.2ms preprocess, 1269.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1265.3ms
# Speed: 7.2ms preprocess, 1265.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1307.8ms
# Speed: 5.9ms preprocess, 1307.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1365.8ms
# Speed: 4.9ms preprocess, 1365.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1286.9ms
# Speed: 4.0ms preprocess, 1286.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1232.3ms
# Speed: 6.1ms preprocess, 1232.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1272.2ms
# Speed: 6.7ms preprocess, 1272.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1220.6ms
# Speed: 4.9ms preprocess, 1220.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1245.3ms
# Speed: 4.8ms preprocess, 1245.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1269.7ms
# Speed: 6.6ms preprocess, 1269.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1386.5ms
# Speed: 12.3ms preprocess, 1386.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1343.3ms
# Speed: 10.5ms preprocess, 1343.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1738.1ms
# Speed: 9.3ms preprocess, 1738.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1344.4ms
# Speed: 7.0ms preprocess, 1344.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1330.7ms
# Speed: 7.6ms preprocess, 1330.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 